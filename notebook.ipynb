# %%
import cv2
import numpy as np
from luv import RGB2LUV
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from segmentationLUV import *
from segmentationRGB import *
import cv2
import numpy as np

# %%
img = cv2.imread('seg-image.png')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
segmentedimg,labels= apply_k_means_luv(source=img)

plt.figure()

plt.subplot(1, 2, 1)
plt.imshow(img_rgb)
plt.axis('off')
plt.title('Original image')

plt.subplot(1, 2, 2)
plt.imshow(segmentedimg)
plt.axis('off')
plt.title(f'Segmented image')

plt.show()

# %%
img = cv2.imread('seg-image.png')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
segmentedimg,labels= apply_k_means_rgb(source=img)
# segmentedimg,labels= apply_mean_shift_rgb(source=img)

plt.figure()

plt.subplot(1, 2, 1)
plt.imshow(img_rgb)
plt.axis('off')
plt.title('Original image')

plt.subplot(1, 2, 2)
plt.imshow(segmentedimg,cmap="gray")
plt.axis('off')
plt.title(f'Segmented image')

plt.show()

# %%
img = cv2.imread('seg-image.png')
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
segmentedimg,labels= agglomerative(img)
# segmentedimg,labels= apply_mean_shift_rgb(source=img)

plt.figure()

plt.subplot(1, 2, 1)
plt.imshow(img_rgb)
plt.axis('off')
plt.title('Original image')

plt.subplot(1, 2, 2)
plt.imshow(segmentedimg,cmap="gray")
plt.axis('off')
plt.title(f'Segmented image')

plt.show()
