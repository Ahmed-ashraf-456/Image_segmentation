# %%
import cv2
import matplotlib.pyplot as plt
from segmantation_using_region_growing import *

# %%
image = plt.imread('images\IMG-20230502-WA0019.jpg')
plt.figure('Original Image')
plt.imshow(image)

# %%
image = cv2.imread('images\IMG-20230502-WA0019.jpg', 0)
seeds = [[200, 300], [300, 295], [310, 350]]
segment_image_class = RegionGrower(image,seeds,6)
segmented_RegGrow = segment_image_class.fit()
plt.imshow(segmented_RegGrow)
